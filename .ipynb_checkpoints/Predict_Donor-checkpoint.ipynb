# %% [markdown]
# ## What is the problem that you’re solving? Who are you solving it for?

# %% [markdown]
# What are potential features, whether already built or that you’ll need to make? What is your target variable?
# What transformations will you need to perform on your input data?
# What modeling approach(es) will you use for your problem? Is this classification or regression?
# How will you evaluate your model’s performance? This should be in terms of quantitative metrics, qualitative evaluation, and visualizations.
# Please also include a rough project timeline, dividing up the work among your group members and demonstrating how you will complete both the analysis and the presentation by May 10th.

# %%
import pandas as pd

# %%
human_rights_data = pd.read_csv('human_rights.csv')
life_expectancy_data = pd.read_csv('Life_Expectancy_Data.csv')
world_happiness_data = pd.read_csv('world_happiness_report.csv')
world_happiness_data = world_happiness_data.rename(columns={"Country name": "Country", "year":"Year"})

merged = pd.merge(human_rights_data, life_expectancy_data, on=["Year","Country"], how='inner') 
merged_data = pd.merge(merged, world_happiness_data, on=["Year","Country"], how='inner')
merged_data
# Out:
#      Year  CIRI Country ID      Country  UN Country ID UN Region  \
# 0    2008              101  Afghanistan            4.0      Asia
# 1    2009              101  Afghanistan            4.0      Asia
# 2    2010              101  Afghanistan            4.0      Asia
# 3    2011              101  Afghanistan            4.0      Asia
# 4    2007              104      Albania            8.0    Europe
# ..    ...              ...          ...            ...       ...
# 592  2007              698     Zimbabwe          716.0    Africa
# 593  2008              698     Zimbabwe          716.0    Africa
# 594  2009              698     Zimbabwe          716.0    Africa
# 595  2010              698     Zimbabwe          716.0    Africa
# 596  2011              698     Zimbabwe          716.0    Africa
#
#           UN Subregion  Physical Integrity Rights Index  Disappearance  \
# 0    Southcentral Asia                              3.0            2.0
# 1    Southcentral Asia                              4.0            2.0
# 2    Southcentral Asia                              3.0            2.0
# 3    Southcentral Asia                              4.0            2.0
# 4      Southern Europe                              7.0            2.0
# ..                 ...                              ...            ...
# 592     Eastern Africa                              1.0            0.0
# 593     Eastern Africa                              0.0            0.0
# 594     Eastern Africa                              0.0            0.0
# 595     Eastern Africa                              1.0            0.0
# 596     Eastern Africa                              2.0            1.0
#
#      Extrajudicial Killing  Political Imprisonment  ...  Schooling  \
# 0                      0.0                     1.0  ...        8.7
# 1                      1.0                     1.0  ...        8.9
# 2                      0.0                     1.0  ...        9.2
# 3                      0.0                     2.0  ...        9.5
# 4                      2.0                     2.0  ...       11.6
# ..                     ...                     ...  ...        ...
# 592                    1.0                     0.0  ...        9.6
# 593                    0.0                     0.0  ...        9.7
# 594                    0.0                     0.0  ...        9.9
# 595                    1.0                     0.0  ...       10.0
# 596                    1.0                     0.0  ...       10.1
#
#      Life Ladder  Log GDP per capita  Social support  \
# 0          3.724               7.370           0.451
# 1          4.402               7.540           0.552
# 2          4.758               7.647           0.539
# 3          3.832               7.620           0.521
# 4          4.634               9.142           0.821
# ..           ...                 ...             ...
# 592        3.280               7.666           0.828
# 593        3.174               7.461           0.843
# 594        4.056               7.563           0.806
# 595        4.682               7.729           0.857
# 596        4.846               7.846           0.865
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 0                               50.80                         0.718
# 1                               51.20                         0.679
# 2                               51.60                         0.600
# 3                               51.92                         0.496
# 4                               65.80                         0.529
# ..                                ...                           ...
# 592                             42.86                         0.456
# 593                             44.14                         0.344
# 594                             45.42                         0.411
# 595                             46.70                         0.665
# 596                             48.12                         0.633
#
#      Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0         0.168                      0.882            0.518            0.258
# 1         0.190                      0.850            0.584            0.237
# 2         0.121                      0.707            0.618            0.275
# 3         0.162                      0.731            0.611            0.267
# 4        -0.009                      0.875            0.553            0.246
# ..          ...                        ...              ...              ...
# 592      -0.082                      0.946            0.661            0.265
# 593      -0.090                      0.964            0.631            0.250
# 594      -0.078                      0.931            0.736            0.218
# 595      -0.093                      0.828            0.748            0.122
# 596      -0.088                      0.830            0.781            0.211
#
# [597 rows x 55 columns]
